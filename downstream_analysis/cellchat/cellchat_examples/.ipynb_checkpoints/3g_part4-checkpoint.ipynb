# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
filepath = 'tmp'

# %%
incoming = pd.read_csv(os.path.join(filepath, 'incoming.csv'), index_col=0)
outgoing = pd.read_csv(os.path.join(filepath, 'outgoing.csv'), index_col=0)

# %%
p14s_incoming = incoming.iloc[:3]
#sort columns by sum
p14s_incoming = p14s_incoming[p14s_incoming.sum().sort_values(ascending=False).index]

p14s_outgoing = outgoing.iloc[:3]
#sort columns by sum
p14s_outgoing = p14s_outgoing[p14s_outgoing.sum().sort_values(ascending=False).index]

# %%
try:
    os.mkdir(os.path.join('figures'))
except FileExistsError:
    pass

try:
    os.mkdir(os.path.join('figures', 'heatmaps'))
except FileExistsError:
    pass

for top_n in range(10, 70, 10):
    plt.figure(figsize=(15, 12))
    sns.heatmap(p14s_incoming[p14s_incoming.columns[:top_n]], square=True, cmap='viridis', annot=False, cbar_kws={'label': 'Intensity'})
    plt.title('Incoming signals across P14 regional subtypes')
    plt.xlabel('Signaling Pathway')
    plt.ylabel('Cell Type')
    plt.savefig(os.path.join('figures', 'heatmaps', f'incoming_heatmap_n{top_n}.pdf'))
    #plt.show()
    plt.close()

    plt.figure(figsize=(10, 8))
    sns.heatmap(p14s_outgoing[p14s_outgoing.columns[:top_n]], square=True, cmap='viridis', annot=False, cbar_kws={'label': 'Intensity'})
    plt.title('outgoing signals across P14 regional subtypes')
    plt.xlabel('Signaling Pathway')
    plt.ylabel('Cell Type')
    plt.savefig(os.path.join('figures', 'heatmaps', f'outgoing_heatmap_n{top_n}.pdf'))
    #plt.show()
    plt.close()

# %% [markdown]
# Contributions

# %%
pathways = p14s_incoming.columns

# %%
try:
    os.mkdir(os.path.join('figures', 'contributions'))
except FileExistsError:
    pass

for curr_path in pathways:
    print(curr_path)
    contribution = pd.read_csv(os.path.join(filepath, f'contribution_{curr_path}.csv'), index_col=0)

    contribution.dropna(inplace=True)

    contribution.reset_index(inplace=True)
    contribution.index = contribution.name.values

    contribution.drop(['name'], axis=1, inplace=True)

    # Plot
    plt.figure(figsize=(10, 6))
    plt.bar(contribution.index.values, contribution['contribution'], color='skyblue')
    plt.xlabel('Interaction', fontsize=12)
    plt.ylabel('Contribution', fontsize=12)
    plt.title(f'Contribution of Different Interactions to the {curr_path} pathway', fontsize=15)
    plt.xticks(rotation=45, ha='right')
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Display the plot
    plt.tight_layout()
    plt.savefig(os.path.join('figures', 'contributions', f'contribution_{curr_path}.pdf'))
    plt.close()
# Out:
# CCL
# ICAM
# PD-L1
# PVR
# MADCAM
# IL1
# CXCL
# PDL2
# THY1
# LCK
# MHC-I
# ADGRG
# L1CAM
# JAM
# ICOS
# CD6
# COMPLEMENT
# IFN-II
# THBS
# FN1
# VIP
# GALECTIN
# ADIPONECTIN
# ADGRE
# GITRL
# CDH1
# RESISTIN
# CD86
# PCDH
# ADGRL
# IGFBP
# IL2
# TNF
# DHEA
# CHEMERIN
# FLRT
# CD80
# BAFF
# GAS
# PROS
# PSAP
# NKG2D
# FASLG
# VEGF
# FGF
# SN
# TULP
# MIF
# PECAM2
# CD48
# SPP1
# CADM
# TGFb
# Prostaglandin
# TENASCIN
# VCAM
# Netrin
# CypA
# DHEAS
# ANGPTL
# PTH
# COLLAGEN
# CD45
# IL4
# PARs
# Desmosterol
# PTN
# WNT
# SELPLG
# ADGRA
# RELN
# MMP
# CDH5
# PLAU
# IL16
# UNC5
# SLITRK
# MHC-II
# BMP
# CD40
# SEMA7
# CLEC
# EDN
# CEACAM
# BTLA
# APRIL
# APP
# RANKL
# CD160
# GCG
# NECTIN
# MK
# SEMA4
# LIFR
# LAMININ
# CSPG4
# NMU
# GDF
# VWF
# PTPRM
# ncWNT
# KLK
# PROCR
# SEMA5
# CD39
# CysLTs
# PTPR
# NEGR
# AGT
# 2-AG
# DMP1
# SEMA6
# ANGPT
# SEMA3
# PERIOSTIN
# Adenosine
# GRN
# Cholesterol
# HSPG
# EPHA
# TAC
# 27HC
# VTN
# HGF
# GALANIN
# ACTIVIN
# NRG
# HH
# RBP4
# LIGHT
# NTS
# GAP
# CHAD
# GDNF
# NOTCH
# ApoB
# EGF
# IGF
# GUCA
# PDGF
# CNTN
# Glutamate
# CSF
# ESAM
# Androsterone
# SLIT
# EPHB
# SELL
# ApoA
# NCAM
# FLT3
# NRXN
# XCR
# KIT
# SerotoninDopamin
# VISFATIN
# CDH
# NGL
# MPZ
# OCLN
# CLDN
# DESMOSOME
# PECAM1
# IL6
# Ach
# Histamine
# LXA4
# APELIN
# ENHO
# DHT
# Androstenedione
# CD137
# MAG
# SOMATOSTATIN
# VISTA
# CD96
# CD34
# CD52
# Testosterone
# 12oxoLTB4
# 12oxoLTB5
# TWEAK
# 5-HT
# AGRN
# NT
# CD200
# ANNEXIN
# LAIR1
# GIPR
# BST2
# SCT
# NGF
# CTSG
